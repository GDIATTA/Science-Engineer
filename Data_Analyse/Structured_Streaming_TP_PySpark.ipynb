# %% [markdown]
# # Utlisation du Spark StructuredStreaming et Spark DataFrames en général

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# Charger les fichiers sur '/databricks-datasets/iot-stream/data-device' comme DataFrame et inspectez-les
#
# Faire les opérations habituelles

# %%
inputPath = '/databricks-datasets/iot-stream/data-device'

# %%
# %fs ls /databricks-datasets/iot-stream/data-device
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00000.json.gz</td><td>part-00000.json.gz</td><td>2610922</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00001.json.gz</td><td>part-00001.json.gz</td><td>2612478</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00002.json.gz</td><td>part-00002.json.gz</td><td>2619023</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00003.json.gz</td><td>part-00003.json.gz</td><td>2620016</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00004.json.gz</td><td>part-00004.json.gz</td><td>2618699</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00005.json.gz</td><td>part-00005.json.gz</td><td>2619772</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00006.json.gz</td><td>part-00006.json.gz</td><td>2619027</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00007.json.gz</td><td>part-00007.json.gz</td><td>2619832</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00008.json.gz</td><td>part-00008.json.gz</td><td>2617893</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00009.json.gz</td><td>part-00009.json.gz</td><td>2619764</td><td>1532465738000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00010.json.gz</td><td>part-00010.json.gz</td><td>2620205</td><td>1532465766000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00011.json.gz</td><td>part-00011.json.gz</td><td>2619880</td><td>1532465768000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00012.json.gz</td><td>part-00012.json.gz</td><td>2619155</td><td>1532465771000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00013.json.gz</td><td>part-00013.json.gz</td><td>2618436</td><td>1532465772000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00014.json.gz</td><td>part-00014.json.gz</td><td>2619029</td><td>1532465773000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00015.json.gz</td><td>part-00015.json.gz</td><td>2619296</td><td>1532465775000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00016.json.gz</td><td>part-00016.json.gz</td><td>2619911</td><td>1532465776000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00017.json.gz</td><td>part-00017.json.gz</td><td>2619952</td><td>1532465776000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00018.json.gz</td><td>part-00018.json.gz</td><td>2619592</td><td>1532465789000</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/data-device/part-00019.json.gz</td><td>part-00019.json.gz</td><td>2620210</td><td>1532465781000</td></tr></tbody></table></div>

# %%
df = spark.read.format("json").load(inputPath)

# %%
df.show(truncate=False)
# Out:
# +--------------+---------+------+------------+---------+--------------------------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |calories_burnt|device_id|id    |miles_walked|num_steps|timestamp                 |user_id|value                                                                                                                                                                    |
# +--------------+---------+------+------------+---------+--------------------------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |250.7         |5        |950000|2.507       |5014     |2018-07-22 06:44:25.732267|24     |{"user_id": 24, "calories_burnt": 250.6999969482422, "num_steps": 5014, "miles_walked": 2.506999969482422, "time_stamp": "2018-07-22 06:44:25.732267", "device_id": 5}   |
# |126.8         |13       |950001|1.268       |2536     |2018-07-21 01:18:10.732306|24     |{"user_id": 24, "calories_burnt": 126.80000305175781, "num_steps": 2536, "miles_walked": 1.2680000066757202, "time_stamp": "2018-07-21 01:18:10.732306", "device_id": 13}|
# |365.7         |5        |950002|3.657       |7314     |2018-07-24 12:42:53.732332|4      |{"user_id": 4, "calories_burnt": 365.70001220703125, "num_steps": 7314, "miles_walked": 3.6570000648498535, "time_stamp": "2018-07-24 12:42:53.732332", "device_id": 5}  |
# |94.0          |17       |950014|0.94        |1880     |2018-07-21 19:24:03.732648|36     |{"user_id": 36, "calories_burnt": 94.0, "num_steps": 1880, "miles_walked": 0.9399999976158142, "time_stamp": "2018-07-21 19:24:03.732648", "device_id": 17}              |
# |78.85         |13       |950015|0.7885      |1577     |2018-07-23 02:51:40.732674|24     |{"user_id": 24, "calories_burnt": 78.8499984741211, "num_steps": 1577, "miles_walked": 0.7885000109672546, "time_stamp": "2018-07-23 02:51:40.732674", "device_id": 13}  |
# |101.40001     |10       |950016|1.014       |2028     |2018-07-22 00:30:38.732701|23     |{"user_id": 23, "calories_burnt": 101.40000915527344, "num_steps": 2028, "miles_walked": 1.0140000581741333, "time_stamp": "2018-07-22 00:30:38.732701", "device_id": 10}|
# |352.15002     |17       |950017|3.5215      |7043     |2018-07-23 17:35:09.732727|22     |{"user_id": 22, "calories_burnt": 352.1500244140625, "num_steps": 7043, "miles_walked": 3.5215001106262207, "time_stamp": "2018-07-23 17:35:09.732727", "device_id": 17} |
# |254.04999     |7        |950018|2.5405      |5081     |2018-07-21 21:51:39.732753|32     |{"user_id": 32, "calories_burnt": 254.04998779296875, "num_steps": 5081, "miles_walked": 2.5404999256134033, "time_stamp": "2018-07-21 21:51:39.732753", "device_id": 7} |
# |516.15        |13       |950019|5.1615      |10323    |2018-07-21 16:05:05.732779|33     |{"user_id": 33, "calories_burnt": 516.1500244140625, "num_steps": 10323, "miles_walked": 5.161499977111816, "time_stamp": "2018-07-21 16:05:05.732779", "device_id": 13} |
# +--------------+---------+------+------------+---------+--------------------------+-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# Afficher le schéma et créer une structure avec ce schéma
# Ceci est nécessaire pour créer un readStream ou le schéma doit être fourni

# %%
df.printSchema()
# Out:
# root
#  |-- calories_burnt: double (nullable = true)
#  |-- device_id: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- miles_walked: double (nullable = true)
#  |-- num_steps: long (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- value: string (nullable = true)

# %%
jsonSchema = StructType(
  [ 
    StructField("calories_burnt", DoubleType(), True),
    StructField("device_id", LongType(), True),
    StructField("id", LongType(), True),
    StructField("miles_walked", DoubleType(), True),
    StructField("num_steps", LongType(), True),
    StructField("timestamp", TimestampType(), True),
    StructField("user_id", LongType(), True),
    StructField("value", StringType(), True)
  ]
)

# %% [markdown]
# Créer un objet readStream et relisez les fichiers ; utiliser le schéma créé avant

# %%
streamingInputDF = (
  spark
    .readStream
    .format("file")
    .schema(jsonSchema)
    .option("maxFilesPerTrigger", 1)  # Treat a sequence of files as a stream by picking one file at a time
    .json(inputPath)
)

# %% [markdown]
# Créer la requête liée au readStream
#
# Utiliser une fenêtre (choisir la durée et la séparation) et grouper par cette fenêtre et l'id de l'appareil
#
# Agréger ensemble min, max, moyenne, somme de calories_burnt, miles_walked, num_steps

# %%
streamingAggDF = (                 
  streamingInputDF
  .withWatermark("timestamp", "1 minutes") \
  .groupBy(
    window("timestamp", "1 hour", "1 hour"),
    streamingInputDF.device_id
  ).agg(
    max(streamingInputDF.calories_burnt).alias("max_cal"),
    max(streamingInputDF.miles_walked).alias("max_miles"),
    max(streamingInputDF.num_steps).alias("max_steps"),
    min(streamingInputDF.calories_burnt).alias("min_cal"),
    min(streamingInputDF.miles_walked).alias("min_miles"),
    min(streamingInputDF.num_steps).alias("min_steps"),
    avg(streamingInputDF.calories_burnt).alias("avg_cal"),
    avg(streamingInputDF.miles_walked).alias("avg_miles"),
    avg(streamingInputDF.num_steps).alias("avg_strps"),
    sum(streamingInputDF.calories_burnt).alias("sum_cal"),
    sum(streamingInputDF.miles_walked).alias("sum_miles"),
    sum(streamingInputDF.num_steps).alias("sum_steps")
  )
)

# %% [markdown]
# Assurer-vous que la source est en streaming

# %%
streamingAggDF.isStreaming
# Out:
# Out[20]: True

# %% [markdown]
# Créer l'objet writeStream avec format "memory"
# Ceci sera le data sink

# %%
query = (
  streamingAggDF
    .writeStream
    .format("memory")        # memory = store in-memory table 
    .queryName("aggs")     # counts = name of the in-memory table
    .outputMode("complete")  # complete = all the counts should be in the table
    .start()
)

# %% [markdown]
# Faire des requêtes répétées au data sink pour assurer qu'il reçoit des données
# Choisir n'importe quelle requête; compter le nombre d'éléments suffit

# %%
spark.sql("select count(*) from aggs").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    2440|
# +--------+

# %%
spark.sql("select * from aggs").show()
# Out:
# +--------------------+---------+---------+---------+---------+---------+---------+---------+------------------+------------------+-----------------+------------------+------------------+---------+
# |              window|device_id|  max_cal|max_miles|max_steps|  min_cal|min_miles|min_steps|           avg_cal|         avg_miles|        avg_strps|           sum_cal|         sum_miles|sum_steps|
# +--------------------+---------+---------+---------+---------+---------+---------+---------+------------------+------------------+-----------------+------------------+------------------+---------+
# |{2018-07-20 20:00...|        9|    575.8|    5.758|    11516|60.000004|      0.6|     1200|325.69603268253974| 3.256960317460317|6513.920634920635| 41037.70011800001|410.37699999999995|   820754|
# |{2018-07-24 12:00...|        9|   577.65|   5.7765|    11553|    55.65|   0.5565|     1113|313.73269253846155|3.1373269230769227|6274.653846153846|       40785.25003|407.85249999999996|   815705|
# |{2018-07-21 04:00...|       15|   579.75|   5.7975|    11595|     54.6|    0.546|     1092| 299.2109215546218| 2.992109243697479|5984.218487394958|35606.099664999994|356.06100000000004|   712122|
# |{2018-07-21 14:00...|        3|   573.35|   5.7335|    11467|58.499996|    0.585|     1170| 293.7761905904762| 2.937761904761905|5875.523809523809|      30846.500012|308.46500000000003|   616930|
# |{2018-07-21 22:00...|       17|    591.9|    5.919|    11838|     56.9|    0.569|     1138| 335.6200827377049| 3.356200819672131|6712.401639344263|      40945.650094|409.45649999999995|   818913|
# |{2018-07-22 05:00...|       19|571.89996|    5.719|    11438|60.100002|    0.601|     1202| 322.7488955441176| 3.227488970588236| 6454.97794117647|43893.849793999994| 438.9385000000001|   877877|
show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    2440|
# +--------+

# %% [markdown]
# Arrêter la requête soit avec une instruction, soit en cliquant sur la cellule

# %%
query.stop()

# %% [markdown]
# Créer un autre objet writeStream avec la même requête
# Cette fois on va écrire sur des fichiers
# Le mode n'est pas "complete" mais "append"
# Donc n'oublier pas le waterMark
# Attention: withWatermark(df.time...) ne marche pas, il faut utliser withWatermark("time"...)

# %%
streamingAggDF = (                 
  streamingInputDF \
  .withWatermark("timestamp", "1 hours") \
  .groupBy(
    window("timestamp", "1 hours", "1 hours"),
    streamingInputDF.device_id
  ).count()
)

# %% [markdown]
# Sauvegarder le datasink sur un répertoire an utilisant un format adapté ; essayer différents formats.
# Est-ce que csv marche ? json ? parquet ?

# %%
# %fs rm -r /FileStore/tables/test_streaming_cp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>

# %%
# %fs rm -r /FileStore/tables/test_streaming_csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>

# %%
# %fs rm -r /FileStore/tables/test_streaming_aggs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>

# %%
# %fs rm -r /FileStore/tables/aggs_parquet

# %%
# %fs rm -r /FileStore/tables/aggs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res4: Boolean = false
# </div>

# %%
# %fs rm -r /FileStore/tables/aggs_c
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res5: Boolean = false
# </div>

# %%
# Better set path and checkpointLocation at the same value

outPath = '/FileStore/tables/aggs'

query = (
  streamingAggDF
  .writeStream
  .format("json")
  .option("checkpointLocation", outPath)
  .option("path", outPath)
  .start()
)

# %% [markdown]
# Liser les données enregistrées dans une base de données et explorez-les ; essayer différentes requêtes sur le DataFrame

# %%
df = spark.read.format('json').load(outPath)

# %%
df.show(truncate=False)
# Out:
# +-----+---------+----------------------------------------------------+
# |count|device_id|window                                              |
# +-----+---------+----------------------------------------------------+
# |43   |18       |{2018-07-20T05:00:00.000Z, 2018-07-20T04:00:00.000Z}|
# |87   |9        |{2018-07-20T20:00:00.000Z, 2018-07-20T19:00:00.000Z}|
# |34   |6        |{2018-07-20T16:00:00.000Z, 2018-07-20T15:00:00.000Z}|
# |46   |16       |{2018-07-20T08:00:00.000Z, 2018-07-20T07:00:00.000Z}|
# |37   |17       |{2018-07-21T13:00:00.000Z, 2018-07-21T12:00:00.000Z}|
# |40   |20       |{2018-07-20T17:00:00.000Z, 2018-07-20T16:00:00.000Z}|
# |42   |20       |{2018-07-23T10:00:00.000Z, 2018-07-23T09:00:00.000Z}|
# |40   |8        |{2018-07-21T05:00:00.000Z, 2018-07-21T04:00:00.000Z}|
# |36   |16       |{2018-07-20T01:00:00.000Z, 2018-07-20T00:00:00.000Z}|
# |55   |15       |{2018-07-24T13:00:00.000Z, 2018-07-24T12:00:00.000Z}|
# |44   |17       |{2018-07-20T05:00:00.000Z, 2018-07-20T04:00:00.000Z}|
# |46   |8        |{2018-07-20T23:00:00.000Z, 2018-07-20T22:00:00.000Z}|
# |38   |4        |{2018-07-24T15:00:00.000Z, 2018-07-24T14:00:00.000Z}|
# |40   |6        |{2018-07-19T22:00:00.000Z, 2018-07-19T21:00:00.000Z}|
# |41   |13       |{2018-07-20T01:00:00.000Z, 2018-07-20T00:00:00.000Z}|
# |45   |12       |{2018-07-22T18:00:00.000Z, 2018-07-22T17:00:00.000Z}|
# |52   |8        |{2018-07-23T02:00:00.000Z, 2018-07-23T01:00:00.000Z}|
# |40   |18       |{2018-07-22T06:00:00.000Z, 2018-07-22T05:00:00.000Z}|
# |32   |10       |{2018-07-20T15:00:00.000Z, 2018-07-20T14:00:00.000Z}|
# |13   |7        |{2018-07-19T19:00:00.000Z, 2018-07-19T18:00:00.000Z}|
# +-----+---------+----------------------------------------------------+
# only showing top 20 rows

# %%
outPath = '/FileStore/tables/aggs_csv'

query = (
  streamingAggDF
  .writeStream
  .format("csv")
  .option("checkpointLocation", outPath)
  .option("path", outPath)
  .start()
)

# %%
outPath = '/FileStore/tables/aggs_parquet'

query = (
  streamingAggDF
  .writeStream
  .format("parquet")
  .option("checkpointLocation", outPath)
  .option("path", outPath)
  .start()
)

# %%
df1 = spark.read.format('parquet').load(outPath)

# %%
df1.show(truncate=False)
# Out:
# +------------------------------------------+---------+-----+
# |window                                    |device_id|count|
# +------------------------------------------+---------+-----+
# |{2018-07-20 04:00:00, 2018-07-20 05:00:00}|18       |43   |
# |{2018-07-20 19:00:00, 2018-07-20 20:00:00}|9        |87   |
# |{2018-07-20 15:00:00, 2018-07-20 16:00:00}|6        |34   |
# |{2018-07-20 07:00:00, 2018-07-20 08:00:00}|16       |46   |
# |{2018-07-21 12:00:00, 2018-07-21 13:00:00}|17       |37   |
# |{2018-07-20 16:00:00, 2018-07-20 17:00:00}|20       |40   |
# |{2018-07-23 09:00:00, 2018-07-23 10:00:00}|20       |42   |
# |{2018-07-21 04:00:00, 2018-07-21 05:00:00}|8        |40   |
# |{2018-07-20 00:00:00, 2018-07-20 01:00:00}|16       |36   |
# |{2018-07-24 12:00:00, 2018-07-24 13:00:00}|15       |55   |
# |{2018-07-20 04:00:00, 2018-07-20 05:00:00}|17       |44   |
# |{2018-07-20 22:00:00, 2018-07-20 23:00:00}|8        |46   |
# |{2018-07-24 14:00:00, 2018-07-24 15:00:00}|4        |38   |
# |{2018-07-19 21:00:00, 2018-07-19 22:00:00}|6        |40   |
# |{2018-07-20 00:00:00, 2018-07-20 01:00:00}|13       |41   |
# |{2018-07-22 17:00:00, 2018-07-22 18:00:00}|12       |45   |
# |{2018-07-23 01:00:00, 2018-07-23 02:00:00}|8        |52   |
# |{2018-07-22 05:00:00, 2018-07-22 06:00:00}|18       |40   |
# |{2018-07-20 14:00:00, 2018-07-20 15:00:00}|10       |32   |
# |{2018-07-19 18:00:00, 2018-07-19 19:00:00}|7        |13   |
# +------------------------------------------+---------+-----+
# only showing top 20 rows

# %%
# %fs rm -r /FileStore/tables/test_streaming_cp

# %%
# %fs rm -r /FileStore/tables/test_streaming_csv

# %%
# %fs rm -r /FileStore/tables/test_streaming_aggs

# %%
# %fs rm -r /FileStore/tables/aggs_parquet

# %%
# %fs rm -r /FileStore/tables/aggs

# %%
# %fs rm -r /FileStore/tables/aggs_c
